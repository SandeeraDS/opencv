# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('../../Data/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
#matplotlib ->RGB
#opencv -> BGR

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_grey = cv2.imread('../../Data/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_grey.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_grey,cmap="graydata:image/png;base64,...")

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5

# %%
h_ratio = 0.5

# %%
new_img=cv2.resize(fix_img,(0,0),fix_img,w_ration,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img=cv2.flip(fix_img,1)
plt.imshow(new_img)

# %%
cv2.imwrite('new_image.jpg',fix_img) 
#save image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-53227c3f5c0d> in <module>
# ----> 1 cv2.imwrite('new_image.jpg',fix_img)
#       2 #save image
#
# NameError: name 'cv2' is not defined

# %%
fig = plt.figure(figsize=(20,8))
ax=fig.add_subplot(111)
ax.imshow(fix_img)
